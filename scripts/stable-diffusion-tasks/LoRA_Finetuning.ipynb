# %%
# !pip install -U peft --quiet

# %%
# !pip install git+https://github.com/huggingface/diffusers
# !pip install accelerate wand
# !pip install -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt

# !accelerate config default
# accelerate configuration saved at $HOME/.cache/huggingface/accelerate/default_config.yaml
# Out:
# Collecting git+https://github.com/huggingface/diffusers
#   Cloning https://github.com/huggingface/diffusers to /tmp/pip-req-build-jg4bpvp_
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-req-build-jg4bpvp_
#   Resolved https://github.com/huggingface/diffusers to commit 92fe689f06bcec27c4f48cb90574c2b9c42c643b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/dist-packages (from diffusers==0.34.0.dev0) (8.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from diffusers==0.34.0.dev0) (3.18.0)
# Requirement already satisfied: huggingface-hub>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from diffusers==0.34.0.dev0) (0.30.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from diffusers==0.34.0.dev0) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers==0.34.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from diffusers==0.34.0.dev0) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from diffusers==0.34.0.dev0) (0.5.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from diffusers==0.34.0.dev0) (11.2.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.0->diffusers==0.34.0.dev0) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.0->diffusers==0.34.0.dev0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.0->diffusers==0.34.0.dev0) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.0->diffusers==0.34.0.dev0) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.0->diffusers==0.34.0.dev0) (4.13.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata->diffusers==0.34.0.dev0) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers==0.34.0.dev0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers==0.34.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers==0.34.0.dev0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers==0.34.0.dev0) (2025.4.26)
# Building wheels for collected packages: diffusers
#   Building wheel for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.34.0.dev0-py3-none-any.whl size=3659265 sha256=183d2191c0749b218e068714b1615a04f20b6576ac17bc1c8e116f314473ade3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-83ix3s5i/wheels/90/fb/48/a310c271ab42899362ff272062ced42133e5c4c9d0ce77df68
# Successfully built diffusers
# Installing collected packages: diffusers
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.33.1
#     Uninstalling diffusers-0.33.1:
#       Successfully uninstalled diffusers-0.33.1
# Successfully installed diffusers-0.34.0.dev0
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Collecting wand
#   Downloading Wand-0.6.13-py2.py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.30.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2025.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->accelerate)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.4.26)
# Downloading Wand-0.6.13-py2.py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 120.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 92.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 64.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.5 MB/s eta 0:00:00
# Installing collected packages: wand, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 wand-0.6.13
# Requirement already satisfied: accelerate>=0.16.0 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 2)) (0.21.0+cu124)
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 3)) (4.51.3)
# Collecting datasets>=2.19.1 (from -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting ftfy (from -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 5))
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (2.18.0)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 7)) (3.1.6)
# Collecting peft==0.7.0 (from -r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8))
#   Downloading peft-0.7.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (4.67.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (0.5.3)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (0.30.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 2)) (11.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.25.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 3)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.25.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.25.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 3)) (0.21.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (2.2.2)
# Collecting xxhash (from datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4))
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec (from torch>=1.13.0->peft==0.7.0->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 8))
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 5)) (0.2.13)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (3.8)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (5.29.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 6)) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 7)) (3.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (3.11.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.25.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.25.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.25.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 3)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.25.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 3)) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.19.1->-r https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/requirements.txt (line 4)) (1.20.0)
# Downloading peft-0.7.0-py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 8.0 MB/s eta 0:00:00
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 23.0 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.7 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.8 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 17.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 15.8 MB/s eta 0:00:00
# Installing collected packages: xxhash, ftfy, fsspec, dill, multiprocess, datasets, peft
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: peft
#     Found existing installation: peft 0.15.2
#     Uninstalling peft-0.15.2:
#       Successfully uninstalled peft-0.15.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed datasets-3.6.0 dill-0.3.8 fsspec-2025.3.0 ftfy-6.3.1 multiprocess-0.70.16 peft-0.7.0 xxhash-3.5.0
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %%
import wandb
import torch
from diffusers import StableDiffusionPipeline, DPMSolverMultistepScheduler, AutoPipelineForText2Image
from huggingface_hub import model_info

# %%
# !wget -q https://raw.githubusercontent.com/huggingface/diffusers/main/examples/text_to_image/train_text_to_image_lora.py

# %%
# !mkdir -p ./finetune_lora/truck_art

# !accelerate launch --mixed_precision="bf16" train_text_to_image_lora.py \
  --pretrained_model_name_or_path="runwayml/stable-diffusion-v1-5" \
  --dataset_name="ibrahim7004/lora-pak-truck-art" \
  --dataloader_num_workers=8 \
  --resolution=512 \
  --center_crop \
  --random_flip \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --max_train_steps=100 \
  --learning_rate=1e-04 \
  --max_grad_norm=1 \
  --lr_scheduler="cosine" \
  --lr_warmup_steps=0 \
  --output_dir="./finetune_lora/pak_truck_art" \
  --checkpointing_steps=5 \
  --caption_column="caption" \
  --validation_prompt="A colorful Pakistani truck with traditional truck art" \
  --seed=1337
# Out:
# 2025-05-10 11:32:28.052671: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746876748.072306    9990 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746876748.078293    9990 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 05/10/2025 11:32:33 - INFO - __main__ - Distributed environment: DistributedType.NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: bf16
#
# {'rescale_betas_zero_snr', 'thresholding', 'prediction_type', 'variance_type', 'clip_sample_range', 'dynamic_thresholding_ratio', 'sample_max_value', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# {'transformer_layers_per_block', 'num_attention_heads', 'class_embed_type', 'time_cond_proj_dim', 'num_class_embeds', 'mid_block_only_cross_attention', 'time_embedding_type', 'dropout', 'projection_class_embeddings_input_dim', 'timestep_post_act', 'conv_in_kernel', 'cross_attention_norm', 'only_cross_attention', 'mid_block_type', 'upcast_attention', 'reverse_transformer_layers_per_block', 'encoder_hid_dim_type', 'dual_cross_attention', 'addition_embed_type', 'addition_time_embed_dim', 'addition_embed_type_num_heads', 'resnet_skip_time_act', 'encoder_hid_dim', 'resnet_time_scale_shift', 'conv_out_kernel', 'time_embedding_dim', 'class_embeddings_concat', 'use_linear_projection', 'resnet_out_scale_factor', 'time_embedding_act_fn', 'attention_type'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at runwayml/stable-diffusion-v1-5.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# Resolving data files: 100% 17/17 [00:00<00:00, 85.60it/s]
# Downloading data:   6% 1/17 [00:00<00:02,  5.69files/s]
# metadata.csv: 100% 1.67k/1.67k [00:00<00:00, 13.6MB/s]
# Downloading data: 100% 17/17 [00:00<00:00, 39.60files/s]
# Generating train split: 100% 16/16 [00:00<00:00, 650.09 examples/s]
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 05/10/2025 11:32:40 - INFO - __main__ - ***** Running training *****
# 05/10/2025 11:32:40 - INFO - __main__ -   Num examples = 16
# 05/10/2025 11:32:40 - INFO - __main__ -   Num Epochs = 25
# 05/10/2025 11:32:40 - INFO - __main__ -   Instantaneous batch size per device = 1
# 05/10/2025 11:32:40 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 4
# 05/10/2025 11:32:40 - INFO - __main__ -   Gradient Accumulation steps = 4
# 05/10/2025 11:32:40 - INFO - __main__ -   Total optimization steps = 100
# Steps:   4% 4/100 [00:25<09:56,  6.22s/it, lr=9.96e-5, step_loss=0.775]
# model_index.json: 100% 541/541 [00:00<00:00, 4.83MB/s]
#
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
#
# preprocessor_config.json: 100% 342/342 [00:00<00:00, 3.05MB/s]
#
# Fetching 13 files:   8% 1/13 [00:00<00:02,  4.24it/s]
#
# model.safetensors:   0% 0.00/1.22G [00:00<?, ?B/s]
#
#
# config.json: 100% 4.72k/4.72k [00:00<00:00, 38.6MB/s]
#
#
# model.safetensors:   2% 21.0M/1.22G [00:00<00:06, 176MB/s]
#
# model.safetensors:   4% 52.4M/1.22G [00:00<00:05, 228MB/s]
#
# model.safetensors:   8% 94.4M/1.22G [00:00<00:04, 269MB/s]
#
# model.safetensors:  10% 126M/1.22G [00:00<00:03, 284MB/s]
#
# model.safetensors:  13% 157M/1.22G [00:00<00:03, 290MB/s]
#
# model.safetensors:  16% 199M/1.22G [00:00<00:03, 297MB/s]
#
# model.safetensors:  19% 231M/1.22G [00:00<00:03, 300MB/s]
#
# model.safetensors:  22% 262M/1.22G [00:03<00:30, 31.2MB/s]
#
# model.safetensors:  25% 304M/1.22G [00:04<00:19, 46.5MB/s]
#
# model.safetensors:  28% 336M/1.22G [00:04<00:14, 60.1MB/s]
#
# model.safetensors:  30% 367M/1.22G [00:04<00:11, 76.8MB/s]
#
# model.safetensors:  33% 398M/1.22G [00:04<00:08, 96.1MB/s]
#
# model.safetensors:  35% 430M/1.22G [00:04<00:06, 115MB/s]
#
# model.safetensors:  38% 461M/1.22G [00:04<00:05, 139MB/s]
#
# model.safetensors:  41% 493M/1.22G [00:04<00:04, 162MB/s]
#
# model.safetensors:  43% 524M/1.22G [00:04<00:03, 182MB/s]
#
# model.safetensors:  46% 556M/1.22G [00:05<00:03, 195MB/s]
#
# model.safetensors:  48% 587M/1.22G [00:05<00:02, 212MB/s]
#
# model.safetensors:  51% 619M/1.22G [00:05<00:02, 224MB/s]
#
# model.safetensors:  53% 650M/1.22G [00:05<00:02, 224MB/s]
#
# model.safetensors:  56% 682M/1.22G [00:05<00:02, 231MB/s]
#
# model.safetensors:  59% 713M/1.22G [00:05<00:02, 239MB/s]
#
# model.safetensors:  61% 744M/1.22G [00:05<00:01, 256MB/s]
#
# model.safetensors:  64% 776M/1.22G [00:05<00:01, 264MB/s]
#
# model.safetensors:  66% 807M/1.22G [00:06<00:01, 274MB/s]
#
# model.safetensors:  69% 839M/1.22G [00:06<00:01, 280MB/s]
#
# model.safetensors:  72% 870M/1.22G [00:06<00:01, 286MB/s]
#
# model.safetensors:  74% 902M/1.22G [00:06<00:01, 286MB/s]
#
# model.safetensors:  78% 944M/1.22G [00:06<00:00, 295MB/s]
#
# model.safetensors:  80% 975M/1.22G [00:06<00:00, 286MB/s]
#
# model.safetensors:  83% 1.01G/1.22G [00:06<00:00, 288MB/s]
#
# model.safetensors:  85% 1.04G/1.22G [00:06<00:00, 286MB/s]
#
# model.safetensors:  88% 1.07G/1.22G [00:06<00:00, 282MB/s]
#
# model.safetensors:  91% 1.10G/1.22G [00:07<00:00, 288MB/s]
#
# model.safetensors:  93% 1.13G/1.22G [00:07<00:00, 291MB/s]
#
# model.safetensors:  96% 1.16G/1.22G [00:07<00:00, 294MB/s]
#
# model.safetensors: 100% 1.22G/1.22G [00:07<00:00, 162MB/s]
#
# Fetching 13 files: 100% 13/13 [00:07<00:00,  1.68it/s]
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:00,  5.21it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:00,  3.34it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:02<00:00,  3.20it/s]
# 05/10/2025 11:33:17 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps:   5% 5/100 [02:43<1:24:47, 53.55s/it, lr=9.96e-5, step_loss=0.273]05/10/2025 11:35:23 - INFO - accelerate.accelerator - Saving current state to ./finetune_lora/pak_truck_art/checkpoint-5
# 05/10/2025 11:35:55 - INFO - accelerate.checkpointing - Model weights saved in finetune_lora/pak_truck_art/checkpoint-5/model.safetensors
# 05/10/2025 11:35:55 - INFO - accelerate.checkpointing - Optimizer state saved in finetune_lora/pak_truck_art/checkpoint-5/optimizer.bin
# 05/10/2025 11:35:55 - INFO - accelerate.checkpointing - Scheduler state saved in finetune_lora/pak_truck_art/checkpoint-5/scheduler.bin
# 05/10/2025 11:35:55 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in finetune_lora/pak_truck_art/checkpoint-5/sampler.bin
# 05/10/2025 11:35:55 - INFO - accelerate.checkpointing - Random states saved in finetune_lora/pak_truck_art/checkpoint-5/random_states_0.pkl
# Model weights saved in finetune_lora/pak_truck_art/checkpoint-5/pytorch_lora_weights.safetensors
# 05/10/2025 11:35:55 - INFO - __main__ - Saved state to ./finetune_lora/pak_truck_art/checkpoint-5
# Steps:   8% 8/100 [03:35<39:58, 26.07s/it, lr=9.84e-5, step_loss=0.169]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:02<00:06,  1.23s/it]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:08<00:06,  2.25s/it]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:09<00:00,  1.32s/it]
# 05/10/2025 11:36:26 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps:  10% 10/100 [06:10<1:09:43, 46.48s/it, lr=9.8e-5, step_loss=0.00339]05/10/2025 11:38:51 - INFO - accelerate.accelerator - Saving current state to ./finetune_lora/pak_truck_art/checkpoint-10
# 05/10/2025 11:39:28 - INFO - accelerate.checkpointing - Model weights saved in finetune_lora/pak_truck_art/checkpoint-10/model.safetensors
# 05/10/2025 11:39:28 - INFO - accelerate.checkpointing - Optimizer state saved in finetune_lora/pak_truck_art/checkpoint-10/optimizer.bin
# 05/10/2025 11:39:28 - INFO - accelerate.checkpointing - Scheduler state saved in finetune_lora/pak_truck_art/checkpoint-10/scheduler.bin
# 05/10/2025 11:39:28 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in finetune_lora/pak_truck_art/checkpoint-10/sampler.bin
# 05/10/2025 11:39:28 - INFO - accelerate.checkpointing - Random states saved in finetune_lora/pak_truck_art/checkpoint-10/random_states_0.pkl
# Model weights saved in finetune_lora/pak_truck_art/checkpoint-10/pytorch_lora_weights.safetensors
# 05/10/2025 11:39:28 - INFO - __main__ - Saved state to ./finetune_lora/pak_truck_art/checkpoint-10
# Steps:  12% 12/100 [07:01<49:56, 34.05s/it, lr=9.65e-5, step_loss=0.0664]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:00,  6.64it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:05<00:05,  1.70s/it]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:06<00:00,  1.15it/s]
# 05/10/2025 11:39:49 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps:  15% 15/100 [09:40<51:44, 36.52s/it, lr=9.52e-5, step_loss=0.233]  05/10/2025 11:42:20 - INFO - accelerate.accelerator - Saving current state to ./finetune_lora/pak_truck_art/checkpoint-15
# 05/10/2025 11:43:11 - INFO - accelerate.checkpointing - Model weights saved in finetune_lora/pak_truck_art/checkpoint-15/model.safetensors
# 05/10/2025 11:43:11 - INFO - accelerate.checkpointing - Optimizer state saved in finetune_lora/pak_truck_art/checkpoint-15/optimizer.bin
# 05/10/2025 11:43:11 - INFO - accelerate.checkpointing - Scheduler state saved in finetune_lora/pak_truck_art/checkpoint-15/scheduler.bin
# 05/10/2025 11:43:11 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in finetune_lora/pak_truck_art/checkpoint-15/sampler.bin
# 05/10/2025 11:43:11 - INFO - accelerate.checkpointing - Random states saved in finetune_lora/pak_truck_art/checkpoint-15/random_states_0.pkl
# Model weights saved in finetune_lora/pak_truck_art/checkpoint-15/pytorch_lora_weights.safetensors
# 05/10/2025 11:43:11 - INFO - __main__ - Saved state to ./finetune_lora/pak_truck_art/checkpoint-15
# Steps:  16% 16/100 [10:38<1:00:06, 42.93s/it, lr=9.38e-5, step_loss=0.00628]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:00,  5.74it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:04<00:03,  1.16s/it]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:05<00:00,  1.25it/s]
# 05/10/2025 11:43:24 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps:  20% 20/100 [13:23<39:44, 29.81s/it, lr=9.14e-5, step_loss=0.226]05/10/2025 11:46:04 - INFO - accelerate.accelerator - Saving current state to ./finetune_lora/pak_truck_art/checkpoint-20
# 05/10/2025 11:46:25 - INFO - accelerate.checkpointing - Model weights saved in finetune_lora/pak_truck_art/checkpoint-20/model.safetensors
# 05/10/2025 11:46:25 - INFO - accelerate.checkpointing - Optimizer state saved in finetune_lora/pak_truck_art/checkpoint-20/optimizer.bin
# 05/10/2025 11:46:25 - INFO - accelerate.checkpointing - Scheduler state saved in finetune_lora/pak_truck_art/checkpoint-20/scheduler.bin
# 05/10/2025 11:46:25 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in finetune_lora/pak_truck_art/checkpoint-20/sampler.bin
# 05/10/2025 11:46:25 - INFO - accelerate.checkpointing - Random states saved in finetune_lora/pak_truck_art/checkpoint-20/random_states_0.pkl
# Model weights saved in finetune_lora/pak_truck_art/checkpoint-20/pytorch_lora_weights.safetensors
# 05/10/2025 11:46:25 - INFO - __main__ - Saved state to ./finetune_lora/pak_truck_art/checkpoint-20
# Steps:  20% 20/100 [13:44<39:44, 29.81s/it, lr=9.05e-5, step_loss=0.0902]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:00,  7.02it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:03<00:03,  1.05s/it]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:04<00:00,  1.64it/s]
# 05/10/2025 11:46:29 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps:  24% 24/100 [16:28<36:19, 28.67s/it, lr=8.64e-5, step_loss=0.243]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:00,  7.65it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:01,  3.98it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:00,  3.23it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  5.23it/s]
# 05/10/2025 11:49:10 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps:  25% 25/100 [18:48<1:17:36, 62.09s/it, lr=8.64e-5, step_loss=0.374]05/10/2025 11:51:28 - INFO - accelerate.accelerator - Saving current state to ./finetune_lora/pak_truck_art/checkpoint-25
# 05/10/2025 11:52:15 - INFO - accelerate.checkpointing - Model weights saved in finetune_lora/pak_truck_art/checkpoint-25/model.safetensors
# 05/10/2025 11:52:15 - INFO - accelerate.checkpointing - Optimizer state saved in finetune_lora/pak_truck_art/checkpoint-25/optimizer.bin
# 05/10/2025 11:52:15 - INFO - accelerate.checkpointing - Scheduler state saved in finetune_lora/pak_truck_art/checkpoint-25/scheduler.bin
# 05/10/2025 11:52:15 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in finetune_lora/pak_truck_art/checkpoint-25/sampler.bin
# 05/10/2025 11:52:15 - INFO - accelerate.checkpointing - Random states saved in finetune_lora/pak_truck_art/checkpoint-25/random_states_0.pkl
# Model weights saved in finetune_lora/pak_truck_art/checkpoint-25/pytorch_lora_weights.safetensors
# 05/10/2025 11:52:15 - INFO - __main__ - Saved state to ./finetune_lora/pak_truck_art/checkpoint-25
# Steps:  28% 28/100 [19:56<39:29, 32.92s/it, lr=8.19e-5, step_loss=0.00567]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:02<00:05,  1.17s/it]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:04<00:03,  1.07s/it]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:05<00:00,  1.39it/s]
# 05/10/2025 11:52:42 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Steps:  30% 30/100 [22:26<56:27, 48.39s/it, lr=8.06e-5, step_loss=0.17]  05/10/2025 11:55:07 - INFO - accelerate.accelerator - Saving current state to ./finetune_lora/pak_truck_art/checkpoint-30
# 05/10/2025 11:55:48 - INFO - accelerate.checkpointing - Model weights saved in finetune_lora/pak_truck_art/checkpoint-30/model.safetensors
# 05/10/2025 11:55:49 - INFO - accelerate.checkpointing - Optimizer state saved in finetune_lora/pak_truck_art/checkpoint-30/optimizer.bin
# 05/10/2025 11:55:49 - INFO - accelerate.checkpointing - Scheduler state saved in finetune_lora/pak_truck_art/checkpoint-30/scheduler.bin
# 05/10/2025 11:55:49 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in finetune_lora/pak_truck_art/checkpoint-30/sampler.bin
# 05/10/2025 11:55:49 - INFO - accelerate.checkpointing - Random states saved in finetune_lora/pak_truck_art/checkpoint-30/random_states_0.pkl
# Model weights saved in finetune_lora/pak_truck_art/checkpoint-30/pytorch_lora_weights.safetensors
# 05/10/2025 11:55:49 - INFO - __main__ - Saved state to ./finetune_lora/pak_truck_art/checkpoint-30
# Steps:  32% 32/100 [23:22<40:46, 35.98s/it, lr=7.68e-5, step_loss=0.104]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:01<00:04,  1.19it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:02<00:01,  1.65it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:03<00:00,  2.33it/s]
# 05/10/2025 11:56:06 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps:  35% 35/100 [25:55<39:25, 36.40s/it, lr=7.41e-5, step_loss=0.0291]05/10/2025 11:58:36 - INFO - accelerate.accelerator - Saving current state to ./finetune_lora/pak_truck_art/checkpoint-35
# 05/10/2025 11:59:15 - INFO - accelerate.checkpointing - Model weights saved in finetune_lora/pak_truck_art/checkpoint-35/model.safetensors
# 05/10/2025 11:59:15 - INFO - accelerate.checkpointing - Optimizer state saved in finetune_lora/pak_truck_art/checkpoint-35/optimizer.bin
# 05/10/2025 11:59:15 - INFO - accelerate.checkpointing - Scheduler state saved in finetune_lora/pak_truck_art/checkpoint-35/scheduler.bin
# 05/10/2025 11:59:15 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in finetune_lora/pak_truck_art/checkpoint-35/sampler.bin
# 05/10/2025 11:59:16 - INFO - accelerate.checkpointing - Random states saved in finetune_lora/pak_truck_art/checkpoint-35/random_states_0.pkl
# Model weights saved in finetune_lora/pak_truck_art/checkpoint-35/pytorch_lora_weights.safetensors
# 05/10/2025 11:59:16 - INFO - __main__ - Saved state to ./finetune_lora/pak_truck_art/checkpoint-35
# Steps:  36% 36/100 [26:42<42:07, 39.49s/it, lr=7.13e-5, step_loss=0.311] {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:00,  5.00it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.28it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:02<00:00,  2.61it/s]
# 05/10/2025 11:59:26 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps:  40% 40/100 [29:21<28:25, 28.42s/it, lr=6.69e-5, step_loss=0.151]05/10/2025 12:02:02 - INFO - accelerate.accelerator - Saving current state to ./finetune_lora/pak_truck_art/checkpoint-40
# 05/10/2025 12:02:12 - INFO - accelerate.checkpointing - Model weights saved in finetune_lora/pak_truck_art/checkpoint-40/model.safetensors
# 05/10/2025 12:02:13 - INFO - accelerate.checkpointing - Optimizer state saved in finetune_lora/pak_truck_art/checkpoint-40/optimizer.bin
# 05/10/2025 12:02:13 - INFO - accelerate.checkpointing - Scheduler state saved in finetune_lora/pak_truck_art/checkpoint-40/scheduler.bin
# 05/10/2025 12:02:13 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in finetune_lora/pak_truck_art/checkpoint-40/sampler.bin
# 05/10/2025 12:02:13 - INFO - accelerate.checkpointing - Random states saved in finetune_lora/pak_truck_art/checkpoint-40/random_states_0.pkl
# Model weights saved in finetune_lora/pak_truck_art/checkpoint-40/pytorch_lora_weights.safetensors
# 05/10/2025 12:02:13 - INFO - __main__ - Saved state to ./finetune_lora/pak_truck_art/checkpoint-40
# Steps:  40% 40/100 [29:32<28:25, 28.42s/it, lr=6.55e-5, step_loss=0.313]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  14% 1/7 [00:00<00:00,  9.70it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:01,  4.59it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.99it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.94it/s]
# 05/10/2025 12:02:14 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps:  44% 44/100 [32:13<25:15, 27.06s/it, lr=5.94e-5, step_loss=0.254]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:00,  6.01it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:00,  3.70it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  5.84it/s]
# 05/10/2025 12:04:55 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps:  45% 45/100 [34:33<55:47, 60.86s/it, lr=5.94e-5, step_loss=0.026]05/10/2025 12:07:13 - INFO - accelerate.accelerator - Saving current state to ./finetune_lora/pak_truck_art/checkpoint-45
# 05/10/2025 12:07:45 - INFO - accelerate.checkpointing - Model weights saved in finetune_lora/pak_truck_art/checkpoint-45/model.safetensors
# 05/10/2025 12:07:45 - INFO - accelerate.checkpointing - Optimizer state saved in finetune_lora/pak_truck_art/checkpoint-45/optimizer.bin
# 05/10/2025 12:07:45 - INFO - accelerate.checkpointing - Scheduler state saved in finetune_lora/pak_truck_art/checkpoint-45/scheduler.bin
# 05/10/2025 12:07:45 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in finetune_lora/pak_truck_art/checkpoint-45/sampler.bin
# 05/10/2025 12:07:45 - INFO - accelerate.checkpointing - Random states saved in finetune_lora/pak_truck_art/checkpoint-45/random_states_0.pkl
# Model weights saved in finetune_lora/pak_truck_art/checkpoint-45/pytorch_lora_weights.safetensors
# 05/10/2025 12:07:45 - INFO - __main__ - Saved state to ./finetune_lora/pak_truck_art/checkpoint-45
# Steps:  48% 48/100 [35:26<26:15, 30.30s/it, lr=5.31e-5, step_loss=0.274]  {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:00,  6.78it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  1.90it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:02<00:00,  3.43it/s]
# 05/10/2025 12:08:09 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps:  50% 50/100 [37:52<38:29, 46.19s/it, lr=5.16e-5, step_loss=0.0155]05/10/2025 12:10:33 - INFO - accelerate.accelerator - Saving current state to ./finetune_lora/pak_truck_art/checkpoint-50
# 05/10/2025 12:11:14 - INFO - accelerate.checkpointing - Model weights saved in finetune_lora/pak_truck_art/checkpoint-50/model.safetensors
# 05/10/2025 12:11:14 - INFO - accelerate.checkpointing - Optimizer state saved in finetune_lora/pak_truck_art/checkpoint-50/optimizer.bin
# 05/10/2025 12:11:14 - INFO - accelerate.checkpointing - Scheduler state saved in finetune_lora/pak_truck_art/checkpoint-50/scheduler.bin
# 05/10/2025 12:11:14 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in finetune_lora/pak_truck_art/checkpoint-50/sampler.bin
# 05/10/2025 12:11:14 - INFO - accelerate.checkpointing - Random states saved in finetune_lora/pak_truck_art/checkpoint-50/random_states_0.pkl
# Model weights saved in finetune_lora/pak_truck_art/checkpoint-50/pytorch_lora_weights.safetensors
# 05/10/2025 12:11:14 - INFO - __main__ - Saved state to ./finetune_lora/pak_truck_art/checkpoint-50
# Steps:  52% 52/100 [38:47<27:50, 34.80s/it, lr=4.69e-5, step_loss=0.0997] {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:00,  6.75it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.25it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  3.88it/s]
# 05/10/2025 12:11:30 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps:  55% 55/100 [41:19<26:52, 35.84s/it, lr=4.37e-5, step_loss=0.475]05/10/2025 12:14:00 - INFO - accelerate.accelerator - Saving current state to ./finetune_lora/pak_truck_art/checkpoint-55
# 05/10/2025 12:14:56 - INFO - accelerate.checkpointing - Model weights saved in finetune_lora/pak_truck_art/checkpoint-55/model.safetensors
# 05/10/2025 12:14:56 - INFO - accelerate.checkpointing - Optimizer state saved in finetune_lora/pak_truck_art/checkpoint-55/optimizer.bin
# 05/10/2025 12:14:56 - INFO - accelerate.checkpointing - Scheduler state saved in finetune_lora/pak_truck_art/checkpoint-55/scheduler.bin
# 05/10/2025 12:14:56 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in finetune_lora/pak_truck_art/checkpoint-55/sampler.bin
# 05/10/2025 12:14:56 - INFO - accelerate.checkpointing - Random states saved in finetune_lora/pak_truck_art/checkpoint-55/random_states_0.pkl
# Model weights saved in finetune_lora/pak_truck_art/checkpoint-55/pytorch_lora_weights.safetensors
# 05/10/2025 12:14:56 - INFO - __main__ - Saved state to ./finetune_lora/pak_truck_art/checkpoint-55
# Steps:  56% 56/100 [42:22<32:14, 43.96s/it, lr=4.06e-5, step_loss=0.0103]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:01,  4.33it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:00,  3.01it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.12it/s]
# 05/10/2025 12:15:05 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps:  60% 60/100 [44:59<19:27, 29.20s/it, lr=3.61e-5, step_loss=0.332]05/10/2025 12:17:40 - INFO - accelerate.accelerator - Saving current state to ./finetune_lora/pak_truck_art/checkpoint-60
# ...
# 05/10/2025 12:39:16 - INFO - accelerate.checkpointing - Random states saved in finetune_lora/pak_truck_art/checkpoint-85/random_states_0.pkl
# Model weights saved in finetune_lora/pak_truck_art/checkpoint-85/pytorch_lora_weights.safetensors
# 05/10/2025 12:39:16 - INFO - __main__ - Saved state to ./finetune_lora/pak_truck_art/checkpoint-85
# Steps:  88% 88/100 [1:06:57<06:12, 31.04s/it, lr=3.51e-6, step_loss=0.0533]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:00,  6.56it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.36it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.12it/s]
# 05/10/2025 12:39:39 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps:  90% 90/100 [1:09:23<07:46, 46.62s/it, lr=2.96e-6, step_loss=0.643]05/10/2025 12:42:04 - INFO - accelerate.accelerator - Saving current state to ./finetune_lora/pak_truck_art/checkpoint-90
# 05/10/2025 12:42:35 - INFO - accelerate.checkpointing - Model weights saved in finetune_lora/pak_truck_art/checkpoint-90/model.safetensors
# 05/10/2025 12:42:35 - INFO - accelerate.checkpointing - Optimizer state saved in finetune_lora/pak_truck_art/checkpoint-90/optimizer.bin
# 05/10/2025 12:42:35 - INFO - accelerate.checkpointing - Scheduler state saved in finetune_lora/pak_truck_art/checkpoint-90/scheduler.bin
# 05/10/2025 12:42:35 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in finetune_lora/pak_truck_art/checkpoint-90/sampler.bin
# 05/10/2025 12:42:35 - INFO - accelerate.checkpointing - Random states saved in finetune_lora/pak_truck_art/checkpoint-90/random_states_0.pkl
# Model weights saved in finetune_lora/pak_truck_art/checkpoint-90/pytorch_lora_weights.safetensors
# 05/10/2025 12:42:35 - INFO - __main__ - Saved state to ./finetune_lora/pak_truck_art/checkpoint-90
# Steps:  92% 92/100 [1:10:09<04:24, 33.01s/it, lr=1.57e-6, step_loss=0.14]   {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:01,  2.58it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.90it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.47it/s]
# 05/10/2025 12:42:51 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps:  95% 95/100 [1:12:41<02:56, 35.31s/it, lr=8.86e-7, step_loss=0.308]05/10/2025 12:45:22 - INFO - accelerate.accelerator - Saving current state to ./finetune_lora/pak_truck_art/checkpoint-95
# 05/10/2025 12:45:54 - INFO - accelerate.checkpointing - Model weights saved in finetune_lora/pak_truck_art/checkpoint-95/model.safetensors
# 05/10/2025 12:45:54 - INFO - accelerate.checkpointing - Optimizer state saved in finetune_lora/pak_truck_art/checkpoint-95/optimizer.bin
# 05/10/2025 12:45:54 - INFO - accelerate.checkpointing - Scheduler state saved in finetune_lora/pak_truck_art/checkpoint-95/scheduler.bin
# 05/10/2025 12:45:54 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in finetune_lora/pak_truck_art/checkpoint-95/sampler.bin
# 05/10/2025 12:45:54 - INFO - accelerate.checkpointing - Random states saved in finetune_lora/pak_truck_art/checkpoint-95/random_states_0.pkl
# Model weights saved in finetune_lora/pak_truck_art/checkpoint-95/pytorch_lora_weights.safetensors
# 05/10/2025 12:45:54 - INFO - __main__ - Saved state to ./finetune_lora/pak_truck_art/checkpoint-95
# Steps:  96% 96/100 [1:13:20<02:25, 36.38s/it, lr=3.94e-7, step_loss=0.175] {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:02,  2.38it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:01<00:01,  2.86it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.39it/s]
# 05/10/2025 12:46:03 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps: 100% 100/100 [1:16:00<00:00, 27.74s/it, lr=2.47e-8, step_loss=0.17]05/10/2025 12:48:41 - INFO - accelerate.accelerator - Saving current state to ./finetune_lora/pak_truck_art/checkpoint-100
# 05/10/2025 12:48:58 - INFO - accelerate.checkpointing - Model weights saved in finetune_lora/pak_truck_art/checkpoint-100/model.safetensors
# 05/10/2025 12:48:58 - INFO - accelerate.checkpointing - Optimizer state saved in finetune_lora/pak_truck_art/checkpoint-100/optimizer.bin
# 05/10/2025 12:48:58 - INFO - accelerate.checkpointing - Scheduler state saved in finetune_lora/pak_truck_art/checkpoint-100/scheduler.bin
# 05/10/2025 12:48:58 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in finetune_lora/pak_truck_art/checkpoint-100/sampler.bin
# 05/10/2025 12:48:58 - INFO - accelerate.checkpointing - Random states saved in finetune_lora/pak_truck_art/checkpoint-100/random_states_0.pkl
# Model weights saved in finetune_lora/pak_truck_art/checkpoint-100/pytorch_lora_weights.safetensors
# 05/10/2025 12:48:58 - INFO - __main__ - Saved state to ./finetune_lora/pak_truck_art/checkpoint-100
# Steps: 100% 100/100 [1:16:18<00:00, 27.74s/it, lr=0, step_loss=0.0127]    {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:00,  6.39it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:00<00:00,  4.16it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  6.46it/s]
# 05/10/2025 12:49:00 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Model weights saved in finetune_lora/pak_truck_art/pytorch_lora_weights.safetensors
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:00,  6.96it/s]{'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  57% 4/7 [00:00<00:00,  4.28it/s]Instantiating UNet2DConditionModel model under default dtype torch.bfloat16.
# {'transformer_layers_per_block', 'num_attention_heads', 'class_embed_type', 'time_cond_proj_dim', 'num_class_embeds', 'mid_block_only_cross_attention', 'time_embedding_type', 'dropout', 'projection_class_embeddings_input_dim', 'timestep_post_act', 'conv_in_kernel', 'cross_attention_norm', 'only_cross_attention', 'mid_block_type', 'upcast_attention', 'reverse_transformer_layers_per_block', 'encoder_hid_dim_type', 'dual_cross_attention', 'addition_embed_type', 'addition_time_embed_dim', 'addition_embed_type_num_heads', 'resnet_skip_time_act', 'encoder_hid_dim', 'resnet_time_scale_shift', 'conv_out_kernel', 'time_embedding_dim', 'class_embeddings_concat', 'use_linear_projection', 'resnet_out_scale_factor', 'time_embedding_act_fn', 'attention_type'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing UNet2DConditionModel.
#
# All the weights of UNet2DConditionModel were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/unet.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use UNet2DConditionModel for predictions without further training.
# Loaded unet as UNet2DConditionModel from `unet` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...:  71% 5/7 [00:20<00:12,  6.08s/it]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Instantiating AutoencoderKL model under default dtype torch.bfloat16.
# {'shift_factor', 'latents_std', 'use_quant_conv', 'latents_mean', 'use_post_quant_conv', 'mid_block_add_attention', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/vae.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100% 7/7 [00:21<00:00,  3.10s/it]
# Loading unet.
# No LoRA keys associated to CLIPTextModel found with the prefix='text_encoder'. This is safe to ignore if LoRA state dict didn't originally have any CLIPTextModel related params. You can also try specifying `prefix=None` to resolve the warning. Otherwise, open an issue if you think it's unexpected: https://github.com/huggingface/diffusers/issues/new
# 05/10/2025 12:51:32 - INFO - __main__ - Running validation...
#  Generating 4 images with prompt: A colorful Pakistani truck with traditional truck art.
# Steps: 100% 100/100 [1:19:19<00:00, 47.60s/it, lr=0, step_loss=0.0127]

# %%
from diffusers import StableDiffusionPipeline, DPMSolverMultistepScheduler
import torch
from PIL import Image

# Base model
base_model = "runwayml/stable-diffusion-v1-5"

# Load pipeline
pipe = StableDiffusionPipeline.from_pretrained(
    base_model,
    torch_dtype=torch.float16
)

pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)

# Load LoRA weights
pipe.unet.load_attn_procs("./finetune_lora/pak_truck_art/pytorch_lora_weights.safetensors")
pipe.to("cuda")

# Generate image
prompt = "A modern Pakistani truck with vibrant orange floral art and tiger design"
image = pipe(prompt, num_inference_steps=30).images[0]

# Display and save
image.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/diffusers/loaders/unet.py:212: FutureWarning: `load_attn_procs` is deprecated and will be removed in version 0.40.0. Using the `load_attn_procs()` method has been deprecated and will be removed in a future version. Please use `load_lora_adapter()`.
#   deprecate("load_attn_procs", "0.40.0", deprecation_message)
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
# Generate image
prompt = "truck"
image = pipe(prompt, num_inference_steps=30).images[0]

# Display and save
image.show()
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
from IPython.display import display
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
from huggingface_hub import login

login(token="")

# %%
from huggingface_hub import HfApi, HfFolder, upload_folder

api = HfApi()
api.create_repo(repo_id="ibrahim7004/pak-truck-lora", repo_type="model")
upload_folder(repo_id="ibrahim7004/pak-truck-lora", folder_path="./finetune_lora/pak_truck_art", repo_type="model")

# %% [markdown]
# ---
